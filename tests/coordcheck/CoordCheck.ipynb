# %%
from coordcheck import *
from itertools import product
import matplotlib.pyplot as plt

# %% [markdown]
# Note how the standard parametrization (SP) plots below (dark background) all feature some rising or falling curves (bad!), but the maximal update parametrization (μP) plots below (white background) in contrast all have flat curves (good!).

# %%
combo = product(['gpt2', 'bert', 'roberta'], [False, True], [False, True])
for arch, vary_nhead, mup in combo:
  plot_coord_check(arch, mup, vary_nhead, loglog=True, nseeds=3, lr=1e-2)
  plt.show()
# Out:
# 100%|███████████████████████████████████████████| 15/15 [00:22<00:00,  1.51s/it]
# coord check plot saved to gpt2_sp_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:19<00:00,  1.31s/it]
# coord check plot saved to gpt2_mup_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:19<00:00,  1.31s/it]
# coord check plot saved to gpt2_sp_nhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:19<00:00,  1.31s/it]
# coord check plot saved to gpt2_mup_nhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.00s/it]
# coord check plot saved to bert_sp_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:14<00:00,  1.00it/s]
# coord check plot saved to bert_mup_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.01s/it]
# coord check plot saved to bert_sp_nhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.00s/it]
# coord check plot saved to bert_mup_nhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.01s/it]
# coord check plot saved to roberta_sp_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.01s/it]
# coord check plot saved to roberta_mup_dhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.00s/it]
# coord check plot saved to roberta_sp_nhead_coord_check.png
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.01s/it]
# coord check plot saved to roberta_mup_nhead_coord_check.png
